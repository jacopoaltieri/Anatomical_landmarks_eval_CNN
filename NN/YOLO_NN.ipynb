# %%
import os
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-pose.pt')

model.train(data='config.yaml',epochs=30,imgsz=240)
# Out:
# Ultralytics YOLOv8.0.194  Python-3.11.5 torch-2.1.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...
